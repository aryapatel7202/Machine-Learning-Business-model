# %%
import pandas as pd
import numpy as pn
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
df = pd.read_csv(r'1000_Companies.csv')
df
# Out:
#      R&D Spend  Administration  Marketing Spend       State        Profit
# 0    165349.20      136897.800      471784.1000    New York  192261.83000
# 1    162597.70      151377.590      443898.5300  California  191792.06000
# 2    153441.51      101145.550      407934.5400     Florida  191050.39000
# 3    144372.41      118671.850      383199.6200    New York  182901.99000
# 4    142107.34       91391.770      366168.4200     Florida  166187.94000
# ..         ...             ...              ...         ...           ...
# 995   54135.00      118451.999      173232.6695  California   95279.96251
# 996  134970.00      130390.080      329204.0228  California  164336.60550
# 997  100275.47      241926.310      227142.8200  California  413956.48000
# 998  128456.23      321652.140      281692.3200  California  333962.19000
# 999  161181.72      270939.860      295442.1700    New York  476485.43000
#
# [1000 rows x 5 columns]

# %%
X = df[['Administration']]
y = df['Profit']

# %%
X_tr,X_te,y_tr,y_te = train_test_split(X,y,test_size = 0.2,random_state=2)
model = LinearRegression()

# %%
model.fit(X_tr,y_tr)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_te)

# %%
print({'actual':[y_te],'pred':[y_pred]})
# Out:
# {'actual': [37      89949.14000
# 726    181258.40900
# 846     55771.54948
# 295    174329.25160
# 924    151891.28880
#            ...
# 839    136050.16390
# 810    152900.20690
# 930    161467.04080
# 616     63373.88839
# 809    156488.23070
# Name: Profit, Length: 200, dtype: float64], 'pred': [array([-51637.76058895, 144297.9231632 ,  92482.85343061, 141436.78883611,
#        132171.87749023, 138564.71915055, 125740.58639966, 109972.77638978,
#        105423.74560953, 128402.41860568, 141029.71824803, 122985.27614212,
#        101508.24906473, 110912.14262334, 144233.37032074, 142005.06489932,
#        115393.79876429, 102403.16925119, 101598.19975076, 129126.25631149,
#        100534.31331187, 142835.78502764, 106899.99344587, 115024.47227668,
#        100206.61107452, 135360.3615092 , 136319.4817538 , 108423.50960388,
#        139366.16128549, 107211.46951538, 112150.99169269, 144644.67384294,
#        108390.70400617, 124329.24395123, 145834.49090789, 124722.20459968,
# ...

# %%
plt.scatter(X_te,y_te,color='blue',label='actual vs perdicted')
plt.plot(X_te,y_pred,color='r',label="perfect prediction")
plt.legend()
plt.show()

# %%
print("accuracy=",r2_score(y_te,y_pred))
print("absolute error=",mean_absolute_error(y_te,y_pred))
print("squered error=",mean_squared_error(y_te,y_pred))
print("rootsquare=",pn.sqrt(y_te,y_pred))
# Out:
# accuracy= 0.5978457514175957
# absolute error= 20633.301497344124
# squered error= 641835050.1594825
# rootsquare= 37     299.915221
# 726    425.744535
# 846    236.160008
# 295    417.527546
# 924    389.732330
#           ...
# 839    368.849785
# 810    391.024560
# 930    401.829617
# 616    251.741710
# 809    395.585933
# Name: Profit, Length: 200, dtype: float64

# %%
w = model.coef_[0]
b = model.intercept_
if(b<0):
    eq = f'({w} * x) - {-b}'
else:
    eq = f'({w} * x) + {b}'
eq
# Out:
# '(2.3885194221443924 * x) - 174128.53650750034'
